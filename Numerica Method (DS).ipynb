# %%
from math import e, log

import numpy as np

import plotly.express as px

# %% [markdown]
# ## Test Sympson method

# %%
f = lambda x: x**3/47 + 2*log(5/x) - 7*e**(-2*x)

h = 0.001

L = 0+h
R = 3

x = np.arange(L, R, h)
y = [f(i) for i in x]


import plotly.express as px

px.line(x=x, y=y)
# Out:
# <div>                            <div id="e93bb5fd-91e0-4f1f-8342-af54f1f1728f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e93bb5fd-91e0-4f1f-8342-af54f1f1728f")) {                    Plotly.newPlot(                        "e93bb5fd-91e0-4f1f-8342-af54f1f1728f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.010000000000000002,0.011,0.012,0.013000000000000001,0.014000000000000002,0.015,0.016,0.017,0.018000000000000002,0.019000000000000003,0.02,0.021,0.022000000000000002,0.023,0.024,0.025,0.026000000000000002,0.02
# ...

# %%
def runge_kutta_4(x0, y0, derivative, h=0.1):
    y_next = 

    return y_next

# %%
L = 1.7
R = 1.85

N = 20

h = (R-L)/N

alpha = (1+h/3)/(1-h/3)
beta = 4*(h/3)/(1-h/3)


# F(f0, f1, f2 -> v2)
def rk_next(f0, f1, f2):
    K1 = f0
    K2 = f1 * K1
    K3 = f1 * K2
    K4 = f2 * K3
    v2 = v0 + (h/6) * (K1 + 2*K2 + 2*K3 + K4)
    return v2

# F(v0, v2, f0, f1 -> f2)
def f_next(v0, v2, f0, f1):
    f2 = 3*(v2 - v0)/h - f0 - 4*f1
    return f2



v0 = f(L)
v1 = f(L+h)
v2 = f(L+2*h)

f0 = f_deriv(L)
f1 = f_deriv(L+h)
f2 = f_deriv(L+2*h)


interval = [v0, v1, v2]
x = [L, L+h, L+2*h]

for i in range(N-1):
    v2, v1, v0  = v_next(v0, v1, v2), v2, v1
    
    interval.append(v2)
    x.append(x[-1]+h)

print(len(x))
print(len(interval))
# Out:
# 22
# 22

# %%
K1 = f(x0, y0)
K2 = f(x0 + h/2, y0 + (h/2) * K1)
K3 = f(x0 + h/2, y0 + (h/2) * K2)
K4 = f(x0 + h, y0 + h * K3)

y0 += (h/6) * (K1 + 2*K2 + 2*K3 + K4)

# %%
px.line(x=x, y=interval)
# Out:
# <div>                            <div id="1c51aada-9930-4177-b28f-b0351cc72b2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c51aada-9930-4177-b28f-b0351cc72b2d")) {                    Plotly.newPlot(                        "1c51aada-9930-4177-b28f-b0351cc72b2d",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1.7,1.7075,1.7149999999999999,1.7225,1.73,1.7375,1.745,1.7525000000000002,1.7600000000000002,1.7675000000000003,1.7750000000000004,1.7825000000000004,1.7900000000000005,1.7975000000000005,1.8050000000000006,1.8125000000000007,1.8200000000000007,1.82750000000000
# ...

# %%
V(x+2) - V(x) = h/3*(f(x) + 4*f(x+1) + f(x+2))

(v(x+1) - v(x-1))/2h + 4*(v(x+2) - v(x))/2h + (v(x+3) - v(x+1))/2h

v(x+1)/2h - v(x-1)/2h + 2*v(x+2)/h - 2*v(x)/h + v(x+3)/2h - v(x+1)/2h


v(x+3)/2h = h/3*(v(x+2) - v(x)) + v(x-1)/2h + 2*v(x)/h + v(x+1)/2h - v(x+1)/2h - 2*v(x+2)/h

v(x+3) =  2h*h/3*(v(x+2) - v(x)) + v(x-1)/2h + 2*v(x)/h + v(x+1)/2h - v(x+1)/2h - 2*v(x+2)/h
